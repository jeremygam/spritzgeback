# %%
### generates layer 1 ###

import svgwrite
from svgwrite import cm, mm
import csv

dwg = svgwrite.Drawing('spritz_rect_layer_1.svg', profile='tiny')
hk = 0.1 #half kerf width
x_span = [-10.85-5.15, 289.85+5.15]
y_span = [-1.825-3.2, 85.725+3.25]
outer_width = x_span[1] - x_span[0] + 2*hk
outer_height = y_span[1] - y_span[0] + 2*hk

# outer cut outline
dwg.add(dwg.rect((x_span[0]-hk, y_span[0]-hk), (outer_width, outer_height), #slightly bigger for kerf
    stroke = 'black',
    fill = "none",
    rx = 2+hk,
    ry = 2+hk,
    stroke_width=0.1)
)

# mounting hole cuts
with open('Spritzgeback_hole_coordinates.csv', newline='') as csvfile:
    for line in csv.reader(csvfile):
        x = float(line[0])
        y = float(line[1])
        dwg.add(dwg.circle(center=(x,y),
            r=3.96/2-hk,
            stroke='black',
            fill='none',
            stroke_width=0.1)
        )

# cutout for USB
with open('Spritzgeback_USBcutout1_coordinates.csv', newline='') as csvfile:
    points = []    
    for line in csv.reader(csvfile):
        points.append((float(line[0]), float(line[1])))
dwg.add(dwg.polyline(points,
    stroke='black', fill='none',stroke_width=0.1))

    
dwg.save()

# %%
### generates layer 2 ###

import svgwrite
from svgwrite import cm, mm
import csv

dwg = svgwrite.Drawing('spritz_rect_layer_2.svg', profile='tiny')
hk = 0.1 #half kerf width

# outer cut outline
dwg.add(dwg.rect((x_span[0]-hk, y_span[0]-hk), (outer_width, outer_height), #slightly bigger for kerf
    stroke = 'black',
    fill = "none",
    rx = 2+hk,
    ry = 2+hk,
    stroke_width=0.1)
)
# mounting hole cuts
with open('Spritzgeback_hole_coordinates.csv', newline='') as csvfile:
    for line in csv.reader(csvfile):
        x = float(line[0])
        y = float(line[1])
        dwg.add(dwg.circle(center=(x,y),
            r=3.96/2-hk,
            stroke='black',
            fill='none',
            stroke_width=0.1)
        )

# mounting hole cuts
with open('Spritzgeback_hole_coordinates.csv', newline='') as csvfile:
    for line in csv.reader(csvfile):
        x = float(line[0])
        y = float(line[1])
        dwg.add(dwg.circle(center=(x,y),
            r=5-hk-hk,
            stroke='red',
            fill='none',
            stroke_width=0.1)
        )

# cutout for USB
with open('Spritzgeback_USBcutout2_coordinates.csv', newline='') as csvfile:
    points = []    
    for line in csv.reader(csvfile):
        points.append((float(line[0]), float(line[1])))
dwg.add(dwg.polyline(points,
    stroke='black', fill='none',stroke_width=0.1))


# box cutouts for switches
with open('Spritzgeback_switch_coordinates.csv', newline='') as csvfile:
    switch_centers = []    
    for line in csv.reader(csvfile):
        switch_centers.append((float(line[0]), float(line[1])))

for center in switch_centers:
    x = center[0]
    y = center[1]
    points = [(x-7, y-7), (x+7, y-7), (x+7, y+7), (x-7, y+7), (x-7, y-7)]
    #msp.add_lwpolyline(points)
    dwg.add(dwg.polyline(points,
    stroke='black', fill='none',stroke_width=0.1))
    
# cutout for arduino
with open('Spritzgeback_cutout1_coordinates.csv', newline='') as csvfile:
    points = []    
    for line in csv.reader(csvfile):
        points.append((float(line[0]), float(line[1])))
dwg.add(dwg.polyline(points,
    stroke='black', fill='none',stroke_width=0.1))

with open('Spritzgeback_cutout2_coordinates.csv', newline='') as csvfile:
    points = []    
    for line in csv.reader(csvfile):
        points.append((float(line[0]), float(line[1])))
dwg.add(dwg.polyline(points,
    stroke='black', fill='none',stroke_width=0.1))

with open('Spritzgeback_cutout3_coordinates.csv', newline='') as csvfile:
    points = []    
    for line in csv.reader(csvfile):
        points.append((float(line[0]), float(line[1])))
dwg.add(dwg.polyline(points,
    stroke='black', fill='none',stroke_width=0.1))

dwg.save()

# %%
### generates layer 3 ###

import svgwrite
from svgwrite import cm, mm
import csv

dwg = svgwrite.Drawing('spritz_rect_layer_3.svg', profile='tiny')
hk = 0.1 #half kerf width

# outer cut outline
dwg.add(dwg.rect((x_span[0]-hk, y_span[0]-hk), (outer_width, outer_height), #slightly bigger for kerf
    stroke = 'black',
    fill = "none",
    rx = 2+hk,
    ry = 2+hk,
    stroke_width=0.1)
)

# inner cut outline
dwg.add(dwg.rect((-10.85-0.7+hk, -1.825-0.7+hk), (300.7+1.4-2*hk, 87.55+1.4-2*hk), #slightly bigger for kerf
    stroke = 'black',
    fill = "none",
    rx = 2+hk,
    ry = 2+hk,
    stroke_width=0.1)
)

# mounting hole cuts
with open('Spritzgeback_hole_coordinates.csv', newline='') as csvfile:
    for line in csv.reader(csvfile):
        x = float(line[0])
        y = float(line[1])
        dwg.add(dwg.circle(center=(x,y),
            r=4.22/2-hk,
            stroke='black',
            fill='none',
            stroke_width=0.1)
        )
        
# cutout for USB
with open('Spritzgeback_USBcutout1_coordinates.csv', newline='') as csvfile:
    points = []    
    for line in csv.reader(csvfile):
        points.append((float(line[0]), float(line[1])))
dwg.add(dwg.polyline(points,
    stroke='red', fill='none',stroke_width=0.1))


dwg.save()

# %%
### generates layer 4 ###

import svgwrite
from svgwrite import cm, mm
import csv

dwg = svgwrite.Drawing('spritz_rect_layer_4.svg', profile='tiny')
hk = 0.1 #half kerf width

# outer cut outline
dwg.add(dwg.rect((x_span[0]-hk, y_span[0]-hk), (outer_width, outer_height), #slightly bigger for kerf
    stroke = 'black',
    fill = "none",
    rx = 2+hk,
    ry = 2+hk,
    stroke_width=0.1)
)

# reset hole cutouts
with open('Spritzgeback_reset_coordinates.csv', newline='') as csvfile:
    points = []    
    for line in csv.reader(csvfile):
        points.append((float(line[0]), float(line[1])))
dwg.add(dwg.polyline(points,
    stroke='red', fill='none',stroke_width=0.1))

# mounting hole cuts
with open('Spritzgeback_hole_coordinates.csv', newline='') as csvfile:
    for line in csv.reader(csvfile):
        x = float(line[0])
        y = float(line[1])
        dwg.add(dwg.circle(center=(x,y),
            r=4.22/2-hk, #subtract for kerf plus little extra
            stroke='black',
            fill='none',
            stroke_width=0.1)
        )

# box cutouts for switches
with open('Spritzgeback_switch_coordinates.csv', newline='') as csvfile:
    switch_centers = []    
    for line in csv.reader(csvfile):
        switch_centers.append((float(line[0]), float(line[1])))

for center in switch_centers:
    x = center[0]
    y = center[1]
    dist = 6.9-hk
    points = [(x-dist, y-dist), (x+dist, y-dist), (x+dist, y+dist), (x-dist, y+dist), (x-dist, y-dist)]
    #msp.add_lwpolyline(points)
    dwg.add(dwg.polyline(points,
    stroke='black', fill='none',stroke_width=0.1))
    
dwg.save()

# %%
### generates CAD svg ###

import svgwrite
from svgwrite import cm, mm
import csv

dwg = svgwrite.Drawing('spritz_rect_CAD.svg', profile='tiny')
hk = 0 #half kerf width
x_span = [-10.85-4, 289.85+4]
y_span = [-1.825-2, 85.725+2]
outer_width = x_span[1] - x_span[0] + 2*hk
outer_height = y_span[1] - y_span[0] + 2*hk

# outer cut outline
dwg.add(dwg.rect((x_span[0]-hk, y_span[0]-hk), (outer_width, outer_height), #slightly bigger for kerf
    stroke = 'black',
    fill = "none",
    rx = 2+hk,
    ry = 2+hk,
    stroke_width=0.01)
)

# mounting hole cuts
with open('Spritzgeback_hole_coordinates.csv', newline='') as csvfile:
    for line in csv.reader(csvfile):
        x = float(line[0])
        y = float(line[1])
        dwg.add(dwg.circle(center=(x,y),
            r=3.96/2-hk-0.02, #subtract for kerf plus little extra
            stroke='black',
            fill='none',
            stroke_width=0.01)
        )

## cutout for USB (layer 1)
with open('Spritzgeback_USBcutout1_coordinates.csv', newline='') as csvfile:
    points = []    
    for line in csv.reader(csvfile):
        points.append((float(line[0]), float(line[1])))
dwg.add(dwg.polyline(points,
    stroke='black', fill='none',stroke_width=0.01))
        
# cutout for USB (layer 2)
with open('Spritzgeback_USBcutout2_coordinates.csv', newline='') as csvfile:
    points = []    
    for line in csv.reader(csvfile):
        points.append((float(line[0]), float(line[1])))
dwg.add(dwg.polyline(points,
    stroke='black', fill='none',stroke_width=0.01))


# box cutouts for switches
with open('Spritzgeback_switch_coordinates.csv', newline='') as csvfile:
    switch_centers = []    
    for line in csv.reader(csvfile):
        switch_centers.append((float(line[0]), float(line[1])))

for center in switch_centers:
    x = center[0]
    y = center[1]
    points = [(x-7, y-7), (x+7, y-7), (x+7, y+7), (x-7, y+7), (x-7, y-7)]
    #msp.add_lwpolyline(points)
    dwg.add(dwg.polyline(points,
    stroke='black', fill='none',stroke_width=0.01))
    
# cutout for arduino
with open('Spritzgeback_cutout1_coordinates.csv', newline='') as csvfile:
    points = []    
    for line in csv.reader(csvfile):
        points.append((float(line[0]), float(line[1])))
dwg.add(dwg.polyline(points,
    stroke='blue', fill='none',stroke_width=0.01))

with open('Spritzgeback_cutout2_coordinates.csv', newline='') as csvfile:
    points = []    
    for line in csv.reader(csvfile):
        points.append((float(line[0]), float(line[1])))
dwg.add(dwg.polyline(points,
    stroke='blue', fill='none',stroke_width=0.01))

with open('Spritzgeback_cutout3_coordinates.csv', newline='') as csvfile:
    points = []    
    for line in csv.reader(csvfile):
        points.append((float(line[0]), float(line[1])))
dwg.add(dwg.polyline(points,
    stroke='blue', fill='none',stroke_width=0.01))

# inner cut outline
dwg.add(dwg.rect((-10.85+hk, -1.825+hk), (300.7-2*hk, 87.55-2*hk), #slightly bigger for kerf
    stroke = 'black',
    fill = "none",
    rx = 2+hk,
    ry = 2+hk,
    stroke_width=0.01)
)
    
dwg.save()

# %%
# make fidget

dwg = svgwrite.Drawing('fidget_1p5.svg', profile='tiny')


import itertools
from itertools import product 

width = 1.5

rows = 6-1
cols = 5-1
row_centers = [(10+20*i) for i in range(0,rows+1)]
col_centers = [(10+20*i) for i in range(0,cols+1)]

centers = [(x,y) for x in row_centers for y in col_centers]

count = 0

for center in centers:
    x = center[0]
    y = center[1]
    print(x,y)
    points = [(x-6.8, y-6.8), (x+6.8, y-6.8), (x+6.8, y+6.8), (x-6.8, y+6.8), (x-6.8, y-6.8)]
    dwg.add(dwg.polyline(points,                     
        stroke='black', fill='none',stroke_width=0.2))

    points = [(x-10, y-10), (x+10, y-10), (x+10, y+10), (x-10, y+10), (x-10, y-10)]
    dwg.add(dwg.polyline(points,                     
        stroke='black', fill='none',stroke_width=0.2))

    if count%2 == 0:
        points = [(x-10-width, y-3), (x-10-width, y+3), (x+10+width, y+3), (x+10+width, y-3), (x-10-width, y-3)]
        dwg.add(dwg.polyline(points,                     
            stroke='black', fill='none',stroke_width=0.2))
        print('even')
    else: 
        points = [(x-3, y-10-width), (x+3, y-10-width), (x+3, y+10+width), (x-3, y+10+width), (x-3, y-10-width)]
        dwg.add(dwg.polyline(points,                     
            stroke='black', fill='none',stroke_width=0.2))
        print('odd')
        
    count = count + 1
    print(count)
dwg.save()
# Out:
# 10 10
# even
# 1
# 10 30
# odd
# 2
# 10 50
# even
# 3
# 10 70
# odd
# 4
# 10 90
# even
# 5
# 30 10
# odd
# 6
# 30 30
# even
# 7
# 30 50
# odd
# 8
# 30 70
# even
# 9
# 30 90
# odd
# 10
# 50 10
# even
# 11
# 50 30
# odd
# 12
# 50 50
# even
# 13
# 50 70
# odd
# 14
# 50 90
# even
# 15
# 70 10
# odd
# 16
# 70 30
# even
# 17
# 70 50
# odd
# 18
# 70 70
# even
# 19
# 70 90
# odd
# 20
# 90 10
# even
# 21
# 90 30
# odd
# 22
# 90 50
# even
# 23
# 90 70
# odd
# 24
# 90 90
# even
# 25
# 110 10
# odd
# 26
# 110 30
# even
# 27
# 110 50
# odd
# 28
# 110 70
# even
# 29
# 110 90
# odd
# 30
